# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 

college = pd.read_csv("csv.zip")
college
# Out:
#                            University                          Department  \
# 0             Cornell University (CU)                           Sociology
# 1     Oklahoma State University (OSU)              Counseling psychology
# 2                    Emory University  Biological and Biomedical Sciences
# 3              Boston University (BU)                                PIBS
# 4                    Brown University                    Computer Science
# ...                               ...                                 ...
# 9619             Duke University (DU)                        Biochemistry
# 9620     University of Virginia (UVA)                Chemical Engineering
# 9621             Duke University (DU)              Biomedical Engineering
# 9622     University of Virginia (UVA)                Chemical Engineering
# 9623             Duke University (DU)              Biomedical Engineering
#
#      Overall Pay  LW Ratio Academic Year Program Year 12 M Gross Pay  \
# ...

# %%
college.get('University')
# Out:
# 0               Cornell University (CU)
# 1       Oklahoma State University (OSU)
# 2                      Emory University
# 3                Boston University (BU)
# 4                      Brown University
#                      ...
# 9619               Duke University (DU)
# 9620       University of Virginia (UVA)
# 9621               Duke University (DU)
# 9622       University of Virginia (UVA)
# 9623               Duke University (DU)
# Name: University, Length: 9624, dtype: object
